# %%
from linkedFDR import *

# %%
pathslist = ['/Users/plutzer/Box/CellBio-MajorLab/Users/Rotation Students/Isaac/MS search outputs/12-24-2020_razUniq_seperate/CK1g1/proteinGroups.txt',
            '/Users/plutzer/Box/CellBio-MajorLab/Users/Rotation Students/Isaac/MS search outputs/12-24-2020_razUniq_seperate/CK1g2/proteinGroups.txt',
            '/Users/plutzer/Box/CellBio-MajorLab/Users/Rotation Students/Isaac/MS search outputs/12-24-2020_razUniq_seperate/CK1g3/proteinGroups.txt',
            '/Users/plutzer/Box/CellBio-MajorLab/Users/Rotation Students/Isaac/MS search outputs/12-24-2020_razUniq_seperate/mt_v5/proteinGroups.txt',
            '/Users/plutzer/Box/CellBio-MajorLab/Users/Rotation Students/Isaac/MS search outputs/12-24-2020_razUniq_seperate/parental_30/proteinGroups.txt',
            '/Users/plutzer/Box/CellBio-MajorLab/Users/Rotation Students/Isaac/MS search outputs/12-24-2020_razUniq_seperate/parental_60/proteinGroups.txt',
            '/Users/plutzer/Box/CellBio-MajorLab/Users/Rotation Students/Isaac/MS search outputs/12-24-2020_razUniq_seperate/mt_NES/proteinGroups.txt',
            '/Users/plutzer/Box/CellBio-MajorLab/Users/Rotation Students/Isaac/MS search outputs/12-24-2020_razUniq_seperate/mt_NLS/proteinGroups.txt']

# %%
output_df = linked_FDRs(pathslist)

# %%
output_df.to_csv('/Users/plutzer/majlab/linkedFDR_testOutput.txt',sep = '\t')

# %%
single_list = ['/Users/plutzer/Box/CellBio-MajorLab/Users/Rotation Students/Isaac/MS search outputs/12-9-2020_razorUnique/txt/proteinGroups.txt']

# %%
combined_search_output = linked_FDRs(single_list)
# Out:
# C:\Users\plutzer\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3418: DtypeWarning: Columns (222,223) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
combined_search_output.to_csv('/Users/plutzer/majlab/linkedFDR_combined_search_test.txt',sep = '\t')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-149b51efe86f> in <module>
# ----> 1 combined_search_output.to_csv('/Users/plutzer/majlab/linkedFDR_combined_search_test.txt',sep = '\t')
#
# NameError: name 'combined_search_output' is not defined

# %%
import pandas as pd
import numpy as np

# %%
combined_df = pd.read_csv(pathslist[0],delimiter='\t')

# %%
combined_df
# Out:
#                                             Protein IDs  \
# 0                       CON__ENSEMBL:ENSBTAP00000024146
# 1     sp|O43790|KRT86_HUMAN;CON__O43790;sp|Q14533|KR...
# 2         sp|O76009|KT33A_HUMAN;CON__Q6NTB9;CON__O76009
# 3                                           CON__P00761
# 4         CON__P02533;sp|P02533|K1C14_HUMAN;CON__Q6IFX2
# ...                                                 ...
# 3630                              sp|Q9Y6Q2|STON1_HUMAN
# 3631                              sp|Q9Y6R0|NUMBL_HUMAN
# 3632                              sp|Q9Y6W5|WASF2_HUMAN
# 3633                              sp|Q9Y6Y0|NS1BP_HUMAN
# 3634                              sp|Q9Y6Y8|S23IP_HUMAN
#
#                                    Majority protein IDs Peptide counts (all)  \
# 0                       CON__ENSEMBL:ENSBTAP00000024146                    3
# 1     sp|O43790|KRT86_HUMAN;CON__O43790;sp|Q14533|KR...          14;14;13;13
# ...

# %%
new_df = pd.read_csv(pathslist[1],delimiter='\t')
combined_df = combined_df.merge(new_df,how='outer',on='Gene names')

# %%
combined_df
# Out:
#                                             Protein IDs  \
# 0                       CON__ENSEMBL:ENSBTAP00000024146
# 1     sp|O43790|KRT86_HUMAN;CON__O43790;sp|Q14533|KR...
# 2         sp|O76009|KT33A_HUMAN;CON__Q6NTB9;CON__O76009
# 3                                           CON__P00761
# 4         CON__P02533;sp|P02533|K1C14_HUMAN;CON__Q6IFX2
# ...                                                 ...
# 4197                              sp|Q9Y6B7|AP4B1_HUMAN
# 4198                               sp|Q9Y6D6|BIG1_HUMAN
# 4199                               sp|Q9Y6E2|BZW2_HUMAN
# 4200                               sp|Q9Y6I3|EPN1_HUMAN
# 4201                              sp|Q9Y6K0|CEPT1_HUMAN
#
#                                  Majority protein IDs_x  \
# 0                       CON__ENSEMBL:ENSBTAP00000024146
# 1     sp|O43790|KRT86_HUMAN;CON__O43790;sp|Q14533|KR...
# 2         sp|O76009|KT33A_HUMAN;CON__Q6NTB9;CON__O76009
# 3                                           CON__P00761
# ...

# %%
pathslist = ['\\Users\\plutzer\\Box\\CellBio-MajorLab\\Users\\Rotation Students\\Isaac\\MS search outputs\\CDKs\\CDK10\\txt\\proteinGroups.txt', '\\Users\\plutzer\\Box\\CellBio-MajorLab\\Users\\Rotation Students\\Isaac\\MS search outputs\\CDKs\\CDK12\\txt\\proteinGroups.txt', '\\Users\\plutzer\\Box\\CellBio-MajorLab\\Users\\Rotation Students\\Isaac\\MS search outputs\\CDKs\\CDK13\\txt\\proteinGroups.txt', '\\Users\\plutzer\\Box\\CellBio-MajorLab\\Users\\Rotation Students\\Isaac\\MS search outputs\\CDKs\\CDK14\\txt\\proteinGroups.txt', '\\Users\\plutzer\\Box\\CellBio-MajorLab\\Users\\Rotation Students\\Isaac\\MS search outputs\\CDKs\\CDK15\\txt\\proteinGroups.txt', '\\Users\\plutzer\\Box\\CellBio-MajorLab\\Users\\Rotation Students\\Isaac\\MS search outputs\\CDKs\\CDK16\\txt\\proteinGroups.txt', '\\Users\\plutzer\\Box\\CellBio-MajorLab\\Users\\Rotation Students\\Isaac\\MS search outputs\\CDKs\\CDK17\\txt\\proteinGroups.txt', '\\Users\\plutzer\\Box\\CellBio-MajorLab\\Users\\Rotation Students\\Isaac\\MS search outputs\\CDKs\\CDK18\\txt\\proteinGroups.txt', '\\Users\\plutzer\\Box\\CellBio-MajorLab\\Users\\Rotation Students\\Isaac\\MS search outputs\\CDKs\\CDK19\\txt\\proteinGroups.txt', '\\Users\\plutzer\\Box\\CellBio-MajorLab\\Users\\Rotation Students\\Isaac\\MS search outputs\\CDKs\\CDKL1\\txt\\proteinGroups.txt', '\\Users\\plutzer\\Box\\CellBio-MajorLab\\Users\\Rotation Students\\Isaac\\MS search outputs\\CDKs\\CDKL2\\txt\\proteinGroups.txt', '\\Users\\plutzer\\Box\\CellBio-MajorLab\\Users\\Rotation Students\\Isaac\\MS search outputs\\CDKs\\CDKL3\\txt\\proteinGroups.txt', '\\Users\\plutzer\\Box\\CellBio-MajorLab\\Users\\Rotation Students\\Isaac\\MS search outputs\\CDKs\\CDKL4\\txt\\proteinGroups.txt', '\\Users\\plutzer\\Box\\CellBio-MajorLab\\Users\\Rotation Students\\Isaac\\MS search outputs\\CDKs\\mT\\txt\\proteinGroups.txt', '\\Users\\plutzer\\Box\\CellBio-MajorLab\\Users\\Rotation Students\\Isaac\\MS search outputs\\CDKs\\NES\\txt\\proteinGroups.txt', '\\Users\\plutzer\\Box\\CellBio-MajorLab\\Users\\Rotation Students\\Isaac\\MS search outputs\\CDKs\\NLS\\txt\\proteinGroups.txt', '\\Users\\plutzer\\Box\\CellBio-MajorLab\\Users\\Rotation Students\\Isaac\\MS search outputs\\CDKs\\Parental\\txt\\proteinGroups.txt', '\\Users\\plutzer\\Box\\CellBio-MajorLab\\Users\\Rotation Students\\Isaac\\MS search outputs\\CDKs\\v5\\txt\\proteinGroups.txt']

# %%
combined_df = pd.read_csv(pathslist[0],delimiter = '\t')

for i in range(1,len(pathslist)):
	new_df = pd.read_csv(pathslist[i],delimiter = '\t')
	new_df = new_df[new_df['Score'] > 0] #Filter out any rows where the protein was IDed by site.
	new_df = new_df[new_df['Gene names'].isna() == False] #Filter out any rows without gene names (contaminants)
	print("Loading file: " + pathslist[i] + ' - Size: ' + str(new_df.shape))
	combined_df = combined_df.merge(new_df,how='outer',on='Gene names')
	print(combined_df.shape)
# Out:
# Loading file: \Users\plutzer\Box\CellBio-MajorLab\Users\Rotation Students\Isaac\MS search outputs\CDKs\CDK12\txt\proteinGroups.txt - Size: (1991, 53)
# (2399, 105)
# Loading file: \Users\plutzer\Box\CellBio-MajorLab\Users\Rotation Students\Isaac\MS search outputs\CDKs\CDK13\txt\proteinGroups.txt - Size: (1911, 53)
# (2709, 157)
# Loading file: \Users\plutzer\Box\CellBio-MajorLab\Users\Rotation Students\Isaac\MS search outputs\CDKs\CDK14\txt\proteinGroups.txt - Size: (1853, 53)
# (3251, 209)
# Loading file: \Users\plutzer\Box\CellBio-MajorLab\Users\Rotation Students\Isaac\MS search outputs\CDKs\CDK15\txt\proteinGroups.txt - Size: (1643, 53)
# (3583, 261)
# Loading file: \Users\plutzer\Box\CellBio-MajorLab\Users\Rotation Students\Isaac\MS search outputs\CDKs\CDK16\txt\proteinGroups.txt - Size: (2259, 53)
# (4288, 313)
# Loading file: \Users\plutzer\Box\CellBio-MajorLab\Users\Rotation Students\Isaac\MS search outputs\CDKs\CDK17\txt\proteinGroups.txt - Size: (1983, 53)
# (4489, 365)
# ...

# %%
for path in pathslist:
    dataframe = pd.read_csv(path,delimiter = '\t')
    print('Path: ' + str(len(dataframe)) + ' -- ' + str(len(dataframe.drop_duplicates(subset='Gene names'))))
# Out:
# Path: 1290 -- 1254
# Path: 2156 -- 2101
# Path: 2066 -- 2010
# Path: 1983 -- 1933
# Path: 1823 -- 1776
# Path: 2472 -- 2397
# Path: 2144 -- 2087
# Path: 2121 -- 2061
# Path: 2359 -- 2300
# Path: 1958 -- 1912
# Path: 708 -- 682
# Path: 1754 -- 1709
# Path: 1849 -- 1807
# Path: 520 -- 500
# Path: 697 -- 677
# Path: 770 -- 745
# Path: 904 -- 887
# Path: 949 -- 924
